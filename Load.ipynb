# %%
import dataparser
import time
import pickle
import load_utils

# %% [markdown]
# ## 1) Load dataset(s) and show some basic stats

# %%
rss_title='rss500'
rss_file='data/N3/RSS-500.ttl'
reuters_title='reuters128'
reuters_file='data/N3/Reuters-128.ttl'

n3_title='n3'

limit=100000000 # for testing purposes

# %%
rss_articles=dataparser.load_article_from_nif_file(rss_file, collection=rss_title, limit=limit)

reuters_articles=dataparser.load_article_from_nif_file(reuters_file, collection=reuters_title, limit=limit)

n3_articles=reuters_articles | rss_articles

# %%
print('N3: %d articles loaded!' % len(n3_articles))
# Out:
# N3: 628 articles loaded!

# %%
wes_title='wes2015'
wes_file="data/wes2015-dataset-nif-1.2.rdf"

wes_articles=dataparser.load_article_from_nif_file(wes_file, limit=limit, collection=wes_title)
print('WES2015: %d articles loaded!' % len(wes_articles))

aida_title='aida'
aida_file='data/AIDA-YAGO2-dataset_topicsLowlevel.tsv'

aida_articles=dataparser.load_article_from_conll_file(aida_file)

print('AIDA: %d articles loaded!' % len(aida_articles))
# Out:
# WES2015: 366 articles loaded!
# AIDA: 1393 articles loaded!

# %%
num_mentions_n3 = sum(len(article.entity_mentions) for article in n3_articles)
print("N3: %d mentions in total!" % num_mentions_n3)

num_mentions_wes = sum(len(article.entity_mentions) for article in wes_articles)
print("WES2015: %d mentions in total!" % num_mentions_wes)

num_mentions_aida = sum(len(article.entity_mentions) for article in aida_articles)
print("AIDA: %d mentions in total!" % num_mentions_aida)
# Out:
# N3: 1880 mentions in total!
# WES2015: 28587 mentions in total!
# AIDA: 34929 mentions in total!

# %%
load_utils.store_dataset(aida_title, aida_articles)
load_utils.store_dataset(wes_title, wes_articles)
#store_dataset(rss_title, rss_articles)
#store_dataset(reuters_title, reuters_articles)
load_utils.store_dataset(n3_title, n3_articles)

# %% [markdown]
# **1.1. Inspect encoding**

# %%
for a in rss_articles:
    for entity in a.entity_mentions:
        gold=entity.gold_link
        print(gold)
# Out:
# Bay_Area_Laboratory_Co-operative
# Victor_Conte
# --NME--
# --NME--
# Football_Association_of_Ireland
# Giovanni_Trapattoni
# --NME--
# --NME--
# --NME--
# Dish_Network
# --NME--
# Portland,_Maine
# New_England_Cable_News
# --NME--
# --NME--
# Arab_Community_Center_for_Economic_and_Social_Services
# Arthur_Caplan
# --NME--
# Miami_International_Airport
# --NME--
# --NME--
# --NME--
# Eric_Kearney
# Jon_A._Husted
# Yayoi_Kusama
# New_York
# --NME--
# --NME--
# Major_League_Baseball
# Rico_Brogna
# --NME--
# --NME--
# Federal_Department_of_Economic_Affairs,_Education_and_Research
# Federal_Department_of_Economic_Affairs,_Education_and_Research
# --NME--
# Richard_H._Bernstein
# --NME--
# --NME--
# --NME--
# Nebraska_Cornhuskers_football
# Fox
# --NME--
# --NME--
# Insurance_Institute_for_Highway_Safety
# --NME--
# Roman_Catholic_Archdiocese_of_Portland_in_Oregon
# --NME--
# Gatineau
# San_Francisco–Oakland_Bay_Bridge
# --NME--
# --NME--
# First_Student_(United_States)
# Associated_Press
# --NME--
# Department_for_Education
# --NME--
# --NME--
# Washington,_D.C.
# Cherokee_Village,_Arkansas
# --NME--
# --NME--
# --NME--
# Lewis_County,_West_Virginia
# Ireland,_West_Virginia
# American_Electric_Power
# West_Virginia
# --NME--
# --NME--
# --NME--
# University_of_California,_San_Francisco
# China_Times
# --NME--
# Bureau_of_Land_Management
# --NME--
# --NME--
# --NME--
# ʻEwa_Beach,_Hawaii
# Aiea,_Hawaii
# ESPN
# --NME--
# --NME--
# Socialist_Party_(France)
# Associated_Press
# --NME--
# --NME--
# November
# --NME--
# --NME--
# Grammy_Award
# John_Legend
# --NME--
# --NME--
# Arizona_Cardinals
# Daytona_Beach,_Florida
# --NME--
# --NME--
# Miami_Dolphins
# --NME--
# --NME--
# Oakland_County,_Michigan
# --NME--
# --NME--
# --NME--
# --NME--
# --NME--
# --NME--
# Sheldon_Adelson
# --NME--
# Russia_in_Global_Affairs
# --NME--
# United_States_Department_of_Homeland_Security
# Daryl_Johnson
# W._Bradford_Wilcox
# The_National_Marriage_Project
# --NME--
# --NME--
# Los_Angeles_Dodgers
# Don_Mattingly
# --NME--
# --NME--
# --NME--
# Roman_Catholic_Archdiocese_of_Portland_in_Oregon
# ESPN
# --NME--
# Foley,_Alabama
# Todd_Watson
# CNET
# --NME--
# --NME--
# --NME--
# CBS
# Leslie_Moonves
# Arne_Duncan
# Michelle_Rhee
# California
# Leland_Yee
# --NME--
# --NME--
# --NME--
# --NME--
# Gio_Gonzalez
# San_Francisco_Bay_Area
# --NME--
# --NME--
# Barclays
# --NME--
# --NME--
# --NME--
# --NME--
# --NME--
# Baltimore_Orioles
# Josh_Beckett
# --NME--
# --NME--
# England_cricket_team
# Andrew_Strauss
# Bangor,_Iowa
# --NME--
# --NME--
# --NME--
# --NME--
# Geothermal_Energy_Association
# Boeremag
# --NME--
# --NME--
# --NME--
# Premier_League
# Manchester_City_F.C.
# --NME--
# --NME--
# --NME--
# Rockland,_Maine
# --NME--
# Athens_Regional_Medical_Center
# --NME--
# Highland_Capital_Partners
# --NME--
# --NME--
# Kurla
# Mumbai
# --NME--
# Columbus,_Ohio
# --NME--
# Milton,_Massachusetts
# Department_of_Public_Safety
# Tucson,_Arizona
# --NME--
# --NME--
# --NME--
# --NME--
# Los_Angeles_Lakers
# Kobe_Bryant
# England_cricket_team
# Andrew_Strauss
# --NME--
# --NME--
# --NME--
# London
# --NME--
# Cincinnati_Children's_Hospital_Medical_Center
# --NME--
# --NME--
# --NME--
# BridgeValley_Community_and_Technical_College
# American_Civil_Liberties_Union
# --NME--
# Associated_Press
# --NME--
# Control_Yuan
# --NME--
# Vitaly_Churkin
# United_States
# Maplecroft
# --NME--
# England_cricket_team
# Andrew_Strauss
# --NME--
# Ma_Ying-jeou
# Communist_Party_of_China
# Bo_Xilai
# Federal_Communications_Commission
# Julius_Genachowski
# Fikile_Mbalula
# Caster_Semenya
# Marshall_University
# Doc_Holliday_(American_football)
# Diego_Maradona
# Beijing
# Hearst_Corporation
# --NME--
# --NME--
# Detroit
# Dish_Network
# Maine
# Cecile_Richards
# Planned_Parenthood
# Federal_Highway_Administration
# Victor_Mendez
# National_Taiwan_University_Hospital
# --NME--
# Denver_International_Airport
# --NME--
# Associated_Press
# --NME--
# Carroll_College_(Montana)
# Mike_Van_Diest
# --NME--
# --NME--
# --NME--
# --NME--
# Cosmopolitan_(magazine)
# Helen_Gurley_Brown
# Brad_Pitt
# Jennifer_Aniston
# Bologna
# --NME--
# --NME--
# Indianapolis
# Tampa_Bay_Lightning
# Steven_Stamkos
# Charles_Elachi
# Jet_Propulsion_Laboratory
# Arizona_Cardinals
# Ken_Whisenhunt
# Hezbollah
# Hassan_Nasrallah
# --NME--
# --NME--
# --NME--
# Federal_Bureau_of_Investigation
# --NME--
# Quincy_High_School_(Massachusetts)
# --NME--
# --NME--
# Félix_Hernández
# Seattle_Mariners
# Hillary_Clinton
# Barack_Obama
# Chicago_Bulls
# Tom_Thibodeau
# --NME--
# Bill_Maloney
# --NME--
# --NME--
# --NME--
# --NME--
# --NME--
# --NME--
# Republican_Party_(United_States)
# Mitt_Romney
# Andreas_Seppi
# --NME--
# Hu_Jintao
# Jang_Sung-taek
# Aeroflot
# --NME--
# --NME--
# --NME--
# --NME--
# Henry_H._Kennedy,_Jr.
# --NME--
# --NME--
# --NME--
# --NME--
# Associated_Press
# --NME--
# --NME--
# --NME--
# --NME--
# --NME--
# --NME--
# --NME--
# Félix_Hernández
# Seattle_Mariners
# Colville_tribe
# --NME--
# --NME--
# --NME--
# Republican_Party_(United_States)
# John_Adams
# Associated_Press
# --NME--
# --NME--
# --NME--
# Apple_Inc.
# Steve_Jobs
# --NME--
# --NME--
# Harmonix
# Alex_Rigopulos
# --NME--
# --NME--
# Barclays
# Great_Britain
# --NME--
# --NME--
# Environmental_Defense_Fund
# --NME--
# --NME--
# --NME--
# --NME--
# --NME--
# Marshall_University
# Jim_Donnan
# Republican_Party_(United_States)
# Mitt_Romney
# --NME--
# --NME--
# Kayla_Harrison
# Marblehead,_Massachusetts
# Amnesty_International
# --NME--
# --NME--
# --NME--
# Félix_Hernández
# Seattle_Mariners
# Amazon.com
# Jeff_Bezos
# Tour_de_France
# Alberto_Contador
# --NME--
# --NME--
# George_Mason_University
# --NME--
# Manchester_City_F.C.
# Chelsea_F.C.
# --NME--
# Mohr_Davidow_Ventures
# --NME--
# --NME--
# Chelsea_F.C.
# FA_Cup
# Delta_Air_Lines
# --NME--
# --NME--
# --NME--
# Jeff_Crowe
# Norwest_Venture_Partners
# Olympique_de_Marseille
# Élie_Baup
# Boston_Red_Sox
# Bobby_Valentine
# --NME--
# --NME--
# Ambassador_Bridge
# --NME--
# --NME--
# New_York_Medical_College
# CBS_Sports
# Boomer_Esiason
# --NME--
# --NME--
# --NME--
# UNESCO
# Italy_national_football_team
# Cesare_Prandelli
# American_Civil_Liberties_Union
# --NME--
# Associated_Press
# --NME--
# Kansas_City_Chiefs
# Herm_Edwards
# Dallas_Cowboys
# Tony_Romo
# --NME--
# --NME--
# Illinois
# Jesse_Jackson,_Jr.
# Boston_Red_Sox
# Johnny_Pesky
# --NME--
# --NME--
# Republican_Party_of_Kentucky
# Darrell_Brock_Jr.
# --NME--
# Chilean_Gendarmerie
# --NME--
# --NME--
# --NME--
# --NME--
# Baltimore_Orioles
# Josh_Beckett
# France_women's_national_basketball_team
# Céline_Dumerc
# Coalition_Avenir_Québec
# François_Legault
# University_of_Alabama
# --NME--
# Boston_Red_Sox
# Bobby_Valentine
# Ministry_of_Foreign_Affairs_(Taiwan)
# --NME--
# Boston_Red_Sox
# Larry_Lucchino
# --NME--
# --NME--
# Department_of_Motor_Vehicles
# --NME--
# --NME--
# The_Church_of_Jesus_Christ_of_Latter-day_Saints
# --NME--
# CEGEP
# --NME--
# --NME--
# Larry_Fitzgerald
# Uganda
# Melanie_Sloan
# Citizens_for_Responsibility_and_Ethics_in_Washington
# Davie,_Florida
# --NME--
# --NME--
# Edwards_Air_Force_Base
# Denver
# Aurora,_Colorado
# Illinois
# Luis_Gutiérrez
# Corrections_Corporation_of_America
# --NME--
# --NME--
# --NME--
# --NME--
# --NME--
# --NME--
# Portland,_Maine
# Bobby_Valentine
# Yahoo!
# Tour_de_France
# Alberto_Contador
# Australian_Defence_Force
# Angus_Houston
# Arizona_Cardinals
# Larry_Fitzgerald
# Félix_Hernández
# Seattle_Mariners
# Argentina_national_football_team
# Agustín_Pichot
# --NME--
# CBS_News
# --NME--
# --NME--
# KHOU
# --NME--
# --NME--
# Boomer_Esiason
# --NME--
# Occupational_safety_and_health
# --NME--
# --NME--
# --NME--
# --NME--
# --NME--
# --NME--
# Dunkin'_Donuts
# Boston
# Robert_Guerrero
# --NME--
# Hall_of_fame
# Michael_Irvin
# Bafétimbi_Gomis
# France_national_football_team
# --NME--
# Lewiston_High_School
# --NME--
# --NME--
# Houston_Airport
# --NME--
# Lars_Boom
# Eneco_Tour
# Chelsea_F.C.
# John_Terry
# Boingo_Wireless
# --NME--
# Seattle_Mariners
# Félix_Hernández
# --NME--
# --NME--
# --NME--
# --NME--
# Chicago
# Libertyville,_Illinois
# --NME--
# Stephen_Colbert
# --NME--
# --NME--
# Gander_Mountain
# --NME--
# --NME--
# --NME--
# Financial_Supervisory_Commission_(Republic_of_China)
# --NME--
# Martin_Dempsey
# Joint_Chiefs_of_Staff
# --NME--
# Maryland_State_Police
# --NME--
# --NME--
# --NME--
# --NME--
# Eslite_Bookstore
# --NME--
# --NME--
# U.S._Chemical_Safety_and_Hazard_Investigation_Board
# --NME--
# Republican_Party_of_Kentucky
# --NME--
# --NME--
# --NME--
# --NME--
# Steve_Jobs
# October
# Charles_Aznavour
# Georgia_(country)
# --NME--
# --NME--
# Japan
# Senkaku_Islands
# --NME--
# Appalachian_Trail_Conservancy
# Cleveland_Indians
# Manny_Acta
# --NME--
# West_Virginia_State_University
# --NME--
# --NME--
# --NME--
# United_States_Commercial_Service
# Hendrick_Motorsports
# Dale_Earnhardt,_Jr.
# Associated_Press
# --NME--
# --NME--
# --NME--
# --NME--
# Michigan_Supreme_Court
# --NME--
# --NME--
# --NME--
# National_Hydropower_Association
# Dish_Network
# Maine
# Coconino_National_Forest
# --NME--
# England_cricket_team
# Andrew_Strauss
# --NME--
# --NME--
# Charleston_Gazette-Mail
# --NME--
# --NME--
# --NME--
# Bob_Baffert
# --NME--
# Ir_Amim
# --NME--
# Martin_Dempsey
# Joint_Chiefs_of_Staff
# --NME--
# --NME--
# --NME--
# --NME--
# --NME--
# --NME--
# National_Center_for_Health_Statistics
# Centers_for_Disease_Control_and_Prevention
# Republican_Party_(United_States)
# Mitt_Romney
# Ministry_of_Defence_(Czech_Republic)
# --NME--
# --NME--
# Agence_France-Presse
# --NME--
# --NME--
# --NME--
# --NME--
# --NME--
# --NME--
# --NME--
# Athens_Regional_Medical_Center
# Action_News
# --NME--
# --NME--
# United_States_Citizenship_and_Immigration_Services
# --NME--
# --NME--
# Chrysler
# --NME--
# --NME--
# --NME--
# --NME--
# --NME--
# --NME--
# --NME--
# Atlanta
# Decatur,_Georgia
# --NME--
# Bed_Bath_&_Beyond
# --NME--
# National_Venture_Capital_Association
# New_York_Giants
# Brandon_Belt
# --NME--
# --NME--
# Jobbik
# Gábor_Vona
# --NME--
# --NME--
# The_Detroit_News
# --NME--
# --NME--
# --NME--
# British_Airways
# --NME--
# Real_Madrid_C.F.
# Ángel_Di_María
# --NME--
# Port_authority
# --NME--
# --NME--
# --NME--
# --NME--
# Tyrann_Mathieu
# Chuck_Bednarik_Award
# --NME--
# --NME--
# Apple_Inc.
# Tim_Cook
# --NME--
# --NME--
# General_Motors
# --NME--
# --NME--
# --NME--
# Cleveland_Indians
# Eric_Wedge
# --NME--
# United_States_Navy
# Carolina_Panthers
# --NME--
# Donny_Schatz
# Knoxville_Nationals
# Federal_Highway_Administration
# Victor_Mendez
# Edison_Electric_Institute
# --NME--
# --NME--
# --NME--
# --NME--
# --NME--
# United_States_Department_of_Justice
# --NME--
# --NME--
# Boise_National_Forest
# Martin_Dempsey
# Joint_Chiefs_of_Staff
# --NME--
# --NME--
# --NME--
# China_Central_Television
# Boston_Red_Sox
# Bobby_Valentine
# American_Council_on_Education
# Molly_Corbett_Broad
# BMC_Racing_Team
# Tejay_van_Garderen
# CNN
# Jonathan_Klein_(CNN)
# Charles_Elachi
# Jet_Propulsion_Laboratory
# Kentucky_Wildcats
# John_Calipari
# Baltimore_Orioles
# Josh_Beckett
# --NME--
# --NME--
# Pro_Bowl
# Larry_Fitzgerald
# --NME--
# Wu_Ching-kuo
# London_Olympics
# Sebastian_Coe
# Angelique_Kerber
# Tímea_Babos
# --NME--
# --NME--
# Jesse_Levine
# Donald_Young_(tennis)
# --NME--
# --NME--
# Andrea_Hlaváčková
# Bethanie_Mattek-Sands
# Executive_Yuan
# --NME--
# --NME--
# --NME--
# Marshall_University
# Doc_Holliday_(American_football)
# --NME--
# --NME--
# Cleveland_Browns
# Romeo_Crennel
# BlueScope
# --NME--
# Chevron_Corporation
# --NME--
# Johanna_Larsson_(tennis)
# Casey_Dellacqua
# --NME--
# Brooklyn
# Arne_Duncan
# Washington,_D.C.
# --NME--
# --NME--
# --NME--
# --NME--
# --NME--
# Philadelphia_Daily_News
# Associated_Press
# --NME--
# ILVA
# Bruno_Ferrante
# --NME--
# --NME--
# Most_Valuable_Player
# Peyton_Manning
# MLB_Network
# Harold_Reynolds
# LSU_Tigers_and_Lady_Tigers
# Les_Miles
# Amazon.com
# Jeff_Bezos
# Miami_Dolphins
# Dan_Marino
# Kelley_Blue_Book
# --NME--
# West_Indies_cricket_team
# Chris_Gayle
# --NME--
# Charlie_Summers
# --NME--
# Belgrade,_Maine
# Boston_Red_Sox
# Minnesota_Twins
# --NME--
# NASDAQ
# --NME--
# Cincinnati_Children's_Hospital_Medical_Center
# --NME--
# --NME--
# --NME--
# Cornell_University
# Al-Shabab
# Mogadishu
# --NME--
# --NME--
# Golden_Globe_Award
# Kelsey_Grammer
# Maruti_Suzuki
# --NME--
# --NME--
# West_Virginia_State_University
# Patient_Protection_and_Affordable_Care_Act
# Patient_Protection_and_Affordable_Care_Act
# Evercore_Partners
# --NME--
# Denver
# --NME--
# Lonmin
# --NME--
# Seattle_Mariners
# Eric_Wedge
# China_National_Offshore_Oil_Corporation
# --NME--
# --NME--
# George_Mason_University
# Dan_Rooney
# Pittsburgh_Steelers
# --NME--
# --NME--
# --NME--
# --NME--
# --NME--
# St._Joseph's_Hospital
# --NME--
# Paul_Ryan
# Major_League_Baseball
# John_Smoltz
# --NME--
# United_States_Citizenship_and_Immigration_Services
# --NME--
# United_States_Army
# England_cricket_team
# Andrew_Strauss
# Denver
# Aurora,_Colorado
# Thomas_David_Jones
# NASA
# Roger_Federer
# Bernard_Tomic
# --NME--
# --NME--
# Los_Angeles_Dodgers
# Peter_O'Malley
# --NME--
# --NME--
# --NME--
# --NME--
# Associated_Press
# --NME--
# LSU_Tigers_and_Lady_Tigers
# Les_Miles
# --NME--
# --NME--
# Virtual_world
# --NME--
# Maine_State_Police
# --NME--
# Mayo_Clinic
# --NME--
# --NME--
# --NME--
# American_Electric_Power
# West_Virginia
# European_Commission
# --NME--
# --NME--
# Food_and_Agriculture_Organization
# --NME--
# --NME--
# --NME--
# Paul_Ryan
# Christine_Gregoire
# --NME--
# Fayetteville,_West_Virginia
# --NME--
# New_York_Giants
# Bruce_Bochy
# George_Washington_Colonials
# --NME--
# Clinton,_Ontario
# --NME--
# Darrell_Brock_Jr.
# Republican_Party_of_Kentucky
# General_Motors_Canada
# --NME--
# Stephen_Elop
# Nokia
# Tour_de_France
# Lance_Armstrong
# Nancy_Brinker
# --NME--
# --NME--
# Marshall_Thundering_Herd_football
# --NME--
# --NME--
# --NME--
# --NME--
# Conway,_Arkansas
# --NME--
# --NME--
# Geno_Auriemma
# --NME--
# --NME--
# Laurent_Fignon
# Bernard_Hinault
# --NME--
# --NME--
# --NME--
# --NME--
# --NME--
# United_States_Department_of_Education
# --NME--
# --NME--
# Chicago_White_Sox
# Kevin_Youkilis
# --NME--
# --NME--
# --NME--
# --NME--
# American_Civil_Liberties_Union
# --NME--
# --NME--
# Portland,_Maine
# Hampden_Academy
# --NME--
# --NME--
# United_States
# --NME--
# --NME--
# --NME--
# --NME--
# Washington,_D.C.
# Cathy_L._Lanier
# --NME--
# --NME--
# --NME--
# --NME--
# Republican_Party_(United_States)
# Mitt_Romney
# --NME--
# --NME--
# --NME--
# Raleigh,_North_Carolina
# China
# Senkaku_Islands
# Central_Intelligence_Agency
# George_Tenet
# L.L.Bean
# --NME--
# --NME--
# Roseburg,_Oregon
# --NME--
# --NME--
# Hoover,_Alabama
# --NME--
# Federal_Communications_Commission
# Julius_Genachowski
# Pro_Bowl
# Chad_Johnson_(cornerback)
# Eric_Liddell
# February
# Department_of_Motor_Vehicles
# --NME--
# --NME--
# Madonna_(entertainer)
# Hall_of_fame
# Jerry_Rice
# Department_of_Motor_Vehicles
# --NME--
# --NME--
# --NME--
# LSU_Tigers_and_Lady_Tigers
# Les_Miles
# Hall_of_fame
# Michael_Irvin
# --NME--
# United_States_Bureau_of_Reclamation
# --NME--
# --NME--
# Bangor,_Iowa
# --NME--
# --NME--
# Montclair_Kimberley_Academy
# --NME--
# --NME--
# Goldman_Sachs
# --NME--
# Associated_Press
# --NME--
# General_Motors
# --NME--
# BIMP-EAGA
# --NME--
# --NME--
# --NME--
# Daniel_Yergin
# --NME--
# Apple_Inc.
# --NME--
# --NME--
# Gannett_Company

# %% [markdown]
# ### 2) AGDISTIS annotation

# %%
import systemparser

# %%
for articles in [aida_articles, n3_articles]:
    c=0
    for article in articles:
        original_content = article.content
        new_content=original_content
        for entity in reversed(article.entity_mentions):
            entity_span=new_content[entity.begin_index: entity.end_index]
            new_content=new_content[:entity.begin_index] + '<entity>' + entity_span + '</entity>' + new_content[entity.end_index:]

#        results=ag.disambiguate(new_content)
        results = systemparser.disambiguateAgdistis(new_content)
        dis_entities={}
        for dis_entity in results:
            dis_entities[str(dis_entity['start'])] = load_utils.getLinkRedirect(load_utils.normalizeURL(dis_entity['disambiguatedURL']))
        for entity in article.entity_mentions:
            start = entity.begin_index
            dis_url = dis_entities[str(start)]
            entity.sys_link = dis_url
        c+=1
        print("Article %d out of %d" % (c, len(articles)))
        if c==10000:
            break
            #x='<entity>Barack Obama</entity> arrives in <entity>Washington, D.C.</entity>, and bye <entity>Msdaser</entity>.'
    #len(x)
# Out:
# Article 1 out of 1393
# Article 2 out of 1393
# Article 3 out of 1393
# Article 4 out of 1393
# Article 5 out of 1393
# Article 6 out of 1393
# Article 7 out of 1393
# Article 8 out of 1393
# Article 9 out of 1393
# Article 10 out of 1393
# Article 11 out of 1393
# Article 12 out of 1393
# Article 13 out of 1393
# Article 14 out of 1393
# Article 15 out of 1393
# Article 16 out of 1393
# Article 17 out of 1393
# Article 18 out of 1393
# Article 19 out of 1393
# Article 20 out of 1393
# Article 21 out of 1393
# Article 22 out of 1393
# Article 23 out of 1393
# Article 24 out of 1393
# Article 25 out of 1393
# Article 26 out of 1393
# Article 27 out of 1393
# Article 28 out of 1393
# Article 29 out of 1393
# Article 30 out of 1393
# Article 31 out of 1393
# Article 32 out of 1393
# Article 33 out of 1393
# Article 34 out of 1393
# Article 35 out of 1393
# Article 36 out of 1393
# Article 37 out of 1393
# Article 38 out of 1393
# Article 39 out of 1393
# Article 40 out of 1393
# Article 41 out of 1393
# Article 42 out of 1393
# Article 43 out of 1393
# Article 44 out of 1393
# Article 45 out of 1393
# Article 46 out of 1393
# Article 47 out of 1393
# Article 48 out of 1393
# Article 49 out of 1393
# Article 50 out of 1393
# Article 51 out of 1393
# Article 52 out of 1393
# Article 53 out of 1393
# Article 54 out of 1393
# Article 55 out of 1393
# Article 56 out of 1393
# Article 57 out of 1393
# Article 58 out of 1393
# Article 59 out of 1393
# Article 60 out of 1393
# Article 61 out of 1393
# Article 62 out of 1393
# Article 63 out of 1393
# Article 64 out of 1393
# Article 65 out of 1393
# Article 66 out of 1393
# Article 67 out of 1393
# Article 68 out of 1393
# Article 69 out of 1393
# Article 70 out of 1393
# Article 71 out of 1393
# Article 72 out of 1393
# Article 73 out of 1393
# Article 74 out of 1393
# Article 75 out of 1393
# Article 76 out of 1393
# Article 77 out of 1393
# Article 78 out of 1393
# Article 79 out of 1393
# Article 80 out of 1393
# Article 81 out of 1393
# Article 82 out of 1393
# Article 83 out of 1393
# Article 84 out of 1393
# Article 85 out of 1393
# Article 86 out of 1393
# Article 87 out of 1393
# Article 88 out of 1393
# Article 89 out of 1393
# Article 90 out of 1393
# Article 91 out of 1393
# Article 92 out of 1393
# Article 93 out of 1393
# Article 94 out of 1393
# Article 95 out of 1393
# Article 96 out of 1393
# Article 97 out of 1393
# Article 98 out of 1393
# Article 99 out of 1393
# Article 100 out of 1393
# Article 101 out of 1393
# Article 102 out of 1393
# Article 103 out of 1393
# Article 104 out of 1393
# Article 105 out of 1393
# Article 106 out of 1393
# Article 107 out of 1393
# Article 108 out of 1393
# Article 109 out of 1393
# Article 110 out of 1393
# Article 111 out of 1393
# Article 112 out of 1393
# Article 113 out of 1393
# Article 114 out of 1393
# Article 115 out of 1393
# Article 116 out of 1393
# Article 117 out of 1393
# Article 118 out of 1393
# Article 119 out of 1393
# Article 120 out of 1393
# Article 121 out of 1393
# Article 122 out of 1393
# Article 123 out of 1393
# Article 124 out of 1393
# Article 125 out of 1393
# Article 126 out of 1393
# Article 127 out of 1393
# Article 128 out of 1393
# Article 129 out of 1393
# Article 130 out of 1393
# Article 131 out of 1393
# Article 132 out of 1393
# Article 133 out of 1393
# Article 134 out of 1393
# Article 135 out of 1393
# Article 136 out of 1393
# Article 137 out of 1393
# Article 138 out of 1393
# Article 139 out of 1393
# Article 140 out of 1393
# Article 141 out of 1393
# Article 142 out of 1393
# Article 143 out of 1393
# Article 144 out of 1393
# Article 145 out of 1393
# Article 146 out of 1393
# Article 147 out of 1393
# Article 148 out of 1393
# Article 149 out of 1393
# Article 150 out of 1393
# Article 151 out of 1393
# Article 152 out of 1393
# Article 153 out of 1393
# Article 154 out of 1393
# Article 155 out of 1393
# Article 156 out of 1393
# Article 157 out of 1393
# Article 158 out of 1393
# Article 159 out of 1393
# Article 160 out of 1393
# Article 161 out of 1393
# Article 162 out of 1393
# Article 163 out of 1393
# Article 164 out of 1393
# Article 165 out of 1393
# Article 166 out of 1393
# Article 167 out of 1393
# Article 168 out of 1393
# Article 169 out of 1393
# Article 170 out of 1393
# Article 171 out of 1393
# Article 172 out of 1393
# Article 173 out of 1393
# Article 174 out of 1393
# Article 175 out of 1393
# Article 176 out of 1393
# Article 177 out of 1393
# Article 178 out of 1393
# Article 179 out of 1393
# Article 180 out of 1393
# Article 181 out of 1393
# Article 182 out of 1393
# Article 183 out of 1393
# Article 184 out of 1393
# Article 185 out of 1393
# Article 186 out of 1393
# Article 187 out of 1393
# Article 188 out of 1393
# Article 189 out of 1393
# Article 190 out of 1393
# Article 191 out of 1393
# Article 192 out of 1393
# Article 193 out of 1393
# Article 194 out of 1393
# Article 195 out of 1393
# Article 196 out of 1393
# Article 197 out of 1393
# Article 198 out of 1393
# Article 199 out of 1393
# Article 200 out of 1393
# Article 201 out of 1393
# Article 202 out of 1393
# Article 203 out of 1393
# Article 204 out of 1393
# Article 205 out of 1393
# Article 206 out of 1393
# Article 207 out of 1393
# Article 208 out of 1393
# Article 209 out of 1393
# Article 210 out of 1393
# Article 211 out of 1393
# Article 212 out of 1393
# Article 213 out of 1393
# Article 214 out of 1393
# Article 215 out of 1393
# Article 216 out of 1393
# Article 217 out of 1393
# Article 218 out of 1393
# Article 219 out of 1393
# Article 220 out of 1393
# Article 221 out of 1393
# Article 222 out of 1393
# Article 223 out of 1393
# Article 224 out of 1393
# Article 225 out of 1393
# Article 226 out of 1393
# Article 227 out of 1393
# Article 228 out of 1393
# Article 229 out of 1393
# Article 230 out of 1393
# Article 231 out of 1393
# Article 232 out of 1393
# Article 233 out of 1393
# Article 234 out of 1393
# Article 235 out of 1393
# Article 236 out of 1393
# Article 237 out of 1393
# Article 238 out of 1393
# Article 239 out of 1393
# Article 240 out of 1393
# Article 241 out of 1393
# Article 242 out of 1393
# Article 243 out of 1393
# Article 244 out of 1393
# Article 245 out of 1393
# Article 246 out of 1393
# Article 247 out of 1393
# Article 248 out of 1393
# Article 249 out of 1393
# Article 250 out of 1393
# Article 251 out of 1393
# Article 252 out of 1393
# Article 253 out of 1393
# Article 254 out of 1393
# Article 255 out of 1393
# Article 256 out of 1393
# Article 257 out of 1393
# Article 258 out of 1393
# Article 259 out of 1393
# Article 260 out of 1393
# Article 261 out of 1393
# Article 262 out of 1393
# Article 263 out of 1393
# Article 264 out of 1393
# Article 265 out of 1393
# Article 266 out of 1393
# Article 267 out of 1393
# Article 268 out of 1393
# Article 269 out of 1393
# Article 270 out of 1393
# Article 271 out of 1393
# Article 272 out of 1393
# Article 273 out of 1393
# Article 274 out of 1393
# Article 275 out of 1393
# Article 276 out of 1393
# Article 277 out of 1393
# Article 278 out of 1393
# Article 279 out of 1393
# Article 280 out of 1393
# Article 281 out of 1393
# Article 282 out of 1393
# Article 283 out of 1393
# Article 284 out of 1393
# Article 285 out of 1393
# Article 286 out of 1393
# Article 287 out of 1393
# Article 288 out of 1393
# Article 289 out of 1393
# Article 290 out of 1393
# Article 291 out of 1393
# Article 292 out of 1393
# Article 293 out of 1393
# Article 294 out of 1393
# Article 295 out of 1393
# Article 296 out of 1393
# Article 297 out of 1393
# Article 298 out of 1393
# Article 299 out of 1393
# Article 300 out of 1393
# Article 301 out of 1393
# Article 302 out of 1393
# Article 303 out of 1393
# Article 304 out of 1393
# Article 305 out of 1393
# Article 306 out of 1393
# Article 307 out of 1393
# Article 308 out of 1393
# Article 309 out of 1393
# Article 310 out of 1393
# Article 311 out of 1393
# Article 312 out of 1393
# Article 313 out of 1393
# Article 314 out of 1393
# Article 315 out of 1393
# Article 316 out of 1393
# Article 317 out of 1393
# Article 318 out of 1393
# Article 319 out of 1393
# Article 320 out of 1393
# Article 321 out of 1393
# Article 322 out of 1393
# Article 323 out of 1393
# Article 324 out of 1393
# Article 325 out of 1393
# Article 326 out of 1393
# Article 327 out of 1393
# Article 328 out of 1393
# Article 329 out of 1393
# Article 330 out of 1393
# Article 331 out of 1393
# Article 332 out of 1393
# Article 333 out of 1393
# Article 334 out of 1393
# Article 335 out of 1393
# Article 336 out of 1393
# Article 337 out of 1393
# Article 338 out of 1393
# Article 339 out of 1393
# Article 340 out of 1393
# Article 341 out of 1393
# Article 342 out of 1393
# Article 343 out of 1393
# Article 344 out of 1393
# Article 345 out of 1393
# Article 346 out of 1393
# Article 347 out of 1393
# Article 348 out of 1393
# Article 349 out of 1393
# Article 350 out of 1393
# Article 351 out of 1393
# Article 352 out of 1393
# Article 353 out of 1393
# Article 354 out of 1393
# Article 355 out of 1393
# Article 356 out of 1393
# Article 357 out of 1393
# Article 358 out of 1393
# Article 359 out of 1393
# Article 360 out of 1393
# Article 361 out of 1393
# Article 362 out of 1393
# Article 363 out of 1393
# Article 364 out of 1393
# Article 365 out of 1393
# Article 366 out of 1393
# Article 367 out of 1393
# Article 368 out of 1393
# Article 369 out of 1393
# Article 370 out of 1393
# Article 371 out of 1393
# Article 372 out of 1393
# Article 373 out of 1393
# Article 374 out of 1393
# Article 375 out of 1393
# Article 376 out of 1393
# Article 377 out of 1393
# Article 378 out of 1393
# Article 379 out of 1393
# Article 380 out of 1393
# Article 381 out of 1393
# Article 382 out of 1393
# Article 383 out of 1393
# Article 384 out of 1393
# Article 385 out of 1393
# Article 386 out of 1393
# Article 387 out of 1393
# Article 388 out of 1393
# Article 389 out of 1393
# Article 390 out of 1393
# Article 391 out of 1393
# Article 392 out of 1393
# Article 393 out of 1393
# Article 394 out of 1393
# Article 395 out of 1393
# Article 396 out of 1393
# Article 397 out of 1393
# Article 398 out of 1393
# Article 399 out of 1393
# Article 400 out of 1393
# Article 401 out of 1393
# Article 402 out of 1393
# Article 403 out of 1393
# Article 404 out of 1393
# Article 405 out of 1393
# Article 406 out of 1393
# Article 407 out of 1393
# Article 408 out of 1393
# Article 409 out of 1393
# Article 410 out of 1393
# Article 411 out of 1393
# Article 412 out of 1393
# Article 413 out of 1393
# Article 414 out of 1393
# Article 415 out of 1393
# Article 416 out of 1393
# Article 417 out of 1393
# Article 418 out of 1393
# Article 419 out of 1393
# Article 420 out of 1393
# Article 421 out of 1393
# Article 422 out of 1393
# Article 423 out of 1393
# Article 424 out of 1393
# Article 425 out of 1393
# Article 426 out of 1393
# Article 427 out of 1393
# Article 428 out of 1393
# Article 429 out of 1393
# Article 430 out of 1393
# Article 431 out of 1393
# Article 432 out of 1393
# Article 433 out of 1393
# Article 434 out of 1393
# Article 435 out of 1393
# Article 436 out of 1393
# Article 437 out of 1393
# Article 438 out of 1393
# Article 439 out of 1393
# Article 440 out of 1393
# Article 441 out of 1393
# Article 442 out of 1393
# Article 443 out of 1393
# Article 444 out of 1393
# Article 445 out of 1393
# Article 446 out of 1393
# Article 447 out of 1393
# Article 448 out of 1393
# Article 449 out of 1393
# Article 450 out of 1393
# Article 451 out of 1393
# Article 452 out of 1393
# Article 453 out of 1393
# Article 454 out of 1393
# Article 455 out of 1393
# Article 456 out of 1393
# Article 457 out of 1393
# Article 458 out of 1393
# Article 459 out of 1393
# Article 460 out of 1393
# Article 461 out of 1393
# Article 462 out of 1393
# Article 463 out of 1393
# Article 464 out of 1393
# Article 465 out of 1393
# Article 466 out of 1393
# Article 467 out of 1393
# Article 468 out of 1393
# Article 469 out of 1393
# Article 470 out of 1393
# Article 471 out of 1393
# Article 472 out of 1393
# Article 473 out of 1393
# Article 474 out of 1393
# Article 475 out of 1393
# Article 476 out of 1393
# Article 477 out of 1393
# Article 478 out of 1393
# Article 479 out of 1393
# Article 480 out of 1393
# Article 481 out of 1393
# Article 482 out of 1393
# Article 483 out of 1393
# Article 484 out of 1393
# Article 485 out of 1393
# Article 486 out of 1393
# Article 487 out of 1393
# Article 488 out of 1393
# Article 489 out of 1393
# Article 490 out of 1393
# Article 491 out of 1393
# Article 492 out of 1393
# Article 493 out of 1393
# Article 494 out of 1393
# Article 495 out of 1393
# Article 496 out of 1393
# Article 497 out of 1393
# Article 498 out of 1393
# Article 499 out of 1393
# Article 500 out of 1393
# Article 501 out of 1393
# Article 502 out of 1393
# Article 503 out of 1393
# Article 504 out of 1393
# Article 505 out of 1393
# Article 506 out of 1393
# Article 507 out of 1393
# Article 508 out of 1393
# Article 509 out of 1393
# Article 510 out of 1393
# Article 511 out of 1393
# Article 512 out of 1393
# Article 513 out of 1393
# Article 514 out of 1393
# Article 515 out of 1393
# Article 516 out of 1393
# Article 517 out of 1393
# Article 518 out of 1393
# Article 519 out of 1393
# Article 520 out of 1393
# Article 521 out of 1393
# Article 522 out of 1393
# Article 523 out of 1393
# Article 524 out of 1393
# Article 525 out of 1393
# Article 526 out of 1393
# Article 527 out of 1393
# Article 528 out of 1393
# Article 529 out of 1393
# Article 530 out of 1393
# Article 531 out of 1393
# Article 532 out of 1393
# Article 533 out of 1393
# Article 534 out of 1393
# Article 535 out of 1393
# Article 536 out of 1393
# Article 537 out of 1393
# Article 538 out of 1393
# Article 539 out of 1393
# Article 540 out of 1393
# Article 541 out of 1393
# Article 542 out of 1393
# Article 543 out of 1393
# Article 544 out of 1393
# Article 545 out of 1393
# Article 546 out of 1393
# Article 547 out of 1393
# Article 548 out of 1393
# Article 549 out of 1393
# Article 550 out of 1393
# Article 551 out of 1393
# Article 552 out of 1393
# Article 553 out of 1393
# Article 554 out of 1393
# Article 555 out of 1393
# Article 556 out of 1393
# Article 557 out of 1393
# Article 558 out of 1393
# Article 559 out of 1393
# Article 560 out of 1393
# Article 561 out of 1393
# Article 562 out of 1393
# Article 563 out of 1393
# Article 564 out of 1393
# Article 565 out of 1393
# Article 566 out of 1393
# Article 567 out of 1393
# Article 568 out of 1393
# Article 569 out of 1393
# Article 570 out of 1393
# Article 571 out of 1393
# Article 572 out of 1393
# Article 573 out of 1393
# Article 574 out of 1393
# Article 575 out of 1393
# Article 576 out of 1393
# Article 577 out of 1393
# Article 578 out of 1393
# Article 579 out of 1393
# Article 580 out of 1393
# Article 581 out of 1393
# Article 582 out of 1393
# Article 583 out of 1393
# Article 584 out of 1393
# Article 585 out of 1393
# Article 586 out of 1393
# Article 587 out of 1393
# Article 588 out of 1393
# Article 589 out of 1393
# Article 590 out of 1393
# Article 591 out of 1393
# Article 592 out of 1393
# Article 593 out of 1393
# Article 594 out of 1393
# Article 595 out of 1393
# Article 596 out of 1393
# Article 597 out of 1393
# Article 598 out of 1393
# Article 599 out of 1393
# Article 600 out of 1393
# Article 601 out of 1393
# Article 602 out of 1393
# Article 603 out of 1393
# Article 604 out of 1393
# Article 605 out of 1393
# Article 606 out of 1393
# Article 607 out of 1393
# Article 608 out of 1393
# Article 609 out of 1393
# Article 610 out of 1393
# Article 611 out of 1393
# Article 612 out of 1393
# Article 613 out of 1393
# Article 614 out of 1393
# Article 615 out of 1393
# Article 616 out of 1393
# Article 617 out of 1393
# Article 618 out of 1393
# Article 619 out of 1393
# Article 620 out of 1393
# Article 621 out of 1393
# Article 622 out of 1393
# Article 623 out of 1393
# Article 624 out of 1393
# Article 625 out of 1393
# Article 626 out of 1393
# Article 627 out of 1393
# Article 628 out of 1393
# Article 629 out of 1393
# Article 630 out of 1393
# Article 631 out of 1393
# Article 632 out of 1393
# Article 633 out of 1393
# Article 634 out of 1393
# Article 635 out of 1393
# Article 636 out of 1393
# Article 637 out of 1393
# Article 638 out of 1393
# Article 639 out of 1393
# Article 640 out of 1393
# Article 641 out of 1393
# Article 642 out of 1393
# Article 643 out of 1393
# Article 644 out of 1393
# Article 645 out of 1393
# Article 646 out of 1393
# Article 647 out of 1393
# Article 648 out of 1393
# Article 649 out of 1393
# Article 650 out of 1393
# Article 651 out of 1393
# Article 652 out of 1393
# Article 653 out of 1393
# Article 654 out of 1393
# Article 655 out of 1393
# Article 656 out of 1393
# Article 657 out of 1393
# Article 658 out of 1393
# Article 659 out of 1393
# Article 660 out of 1393
# Article 661 out of 1393
# Article 662 out of 1393
# Article 663 out of 1393
# Article 664 out of 1393
# Article 665 out of 1393
# Article 666 out of 1393
# Article 667 out of 1393
# Article 668 out of 1393
# Article 669 out of 1393
# Article 670 out of 1393
# Article 671 out of 1393
# Article 672 out of 1393
# Article 673 out of 1393
# Article 674 out of 1393
# Article 675 out of 1393
# Article 676 out of 1393
# Article 677 out of 1393
# Article 678 out of 1393
# Article 679 out of 1393
# Article 680 out of 1393
# Article 681 out of 1393
# Article 682 out of 1393
# Article 683 out of 1393
# Article 684 out of 1393
# Article 685 out of 1393
# Article 686 out of 1393
# Article 687 out of 1393
# Article 688 out of 1393
# Article 689 out of 1393
# Article 690 out of 1393
# Article 691 out of 1393
# Article 692 out of 1393
# Article 693 out of 1393
# Article 694 out of 1393
# Article 695 out of 1393
# Article 696 out of 1393
# Article 697 out of 1393
# Article 698 out of 1393
# Article 699 out of 1393
# Article 700 out of 1393
# Article 701 out of 1393
# Article 702 out of 1393
# Article 703 out of 1393
# Article 704 out of 1393
# Article 705 out of 1393
# Article 706 out of 1393
# Article 707 out of 1393
# Article 708 out of 1393
# Article 709 out of 1393
# Article 710 out of 1393
# Article 711 out of 1393
# Article 712 out of 1393
# Article 713 out of 1393
# Article 714 out of 1393
# Article 715 out of 1393
# Article 716 out of 1393
# Article 717 out of 1393
# Article 718 out of 1393
# Article 719 out of 1393
# Article 720 out of 1393
# Article 721 out of 1393
# Article 722 out of 1393
# Article 723 out of 1393
# Article 724 out of 1393
# Article 725 out of 1393
# Article 726 out of 1393
# Article 727 out of 1393
# Article 728 out of 1393
# Article 729 out of 1393
# Article 730 out of 1393
# Article 731 out of 1393
# Article 732 out of 1393
# Article 733 out of 1393
# Article 734 out of 1393
# Article 735 out of 1393
# Article 736 out of 1393
# Article 737 out of 1393
# Article 738 out of 1393
# Article 739 out of 1393
# Article 740 out of 1393
# Article 741 out of 1393
# Article 742 out of 1393
# Article 743 out of 1393
# Article 744 out of 1393
# Article 745 out of 1393
# Article 746 out of 1393
# Article 747 out of 1393
# Article 748 out of 1393
# Article 749 out of 1393
# Article 750 out of 1393
# Article 751 out of 1393
# Article 752 out of 1393
# Article 753 out of 1393
# Article 754 out of 1393
# Article 755 out of 1393
# Article 756 out of 1393
# Article 757 out of 1393
# Article 758 out of 1393
# Article 759 out of 1393
# Article 760 out of 1393
# Article 761 out of 1393
# Article 762 out of 1393
# Article 763 out of 1393
# Article 764 out of 1393
# Article 765 out of 1393
# Article 766 out of 1393
# Article 767 out of 1393
# Article 768 out of 1393
# Article 769 out of 1393
# Article 770 out of 1393
# Article 771 out of 1393
# Article 772 out of 1393
# Article 773 out of 1393
# Article 774 out of 1393
# Article 775 out of 1393
# Article 776 out of 1393
# Article 777 out of 1393
# Article 778 out of 1393
# Article 779 out of 1393
# Article 780 out of 1393
# Article 781 out of 1393
# Article 782 out of 1393
# Article 783 out of 1393
# Article 784 out of 1393
# Article 785 out of 1393
# Article 786 out of 1393
# Article 787 out of 1393
# Article 788 out of 1393
# Article 789 out of 1393
# Article 790 out of 1393
# Article 791 out of 1393
# Article 792 out of 1393
# Article 793 out of 1393
# Article 794 out of 1393
# Article 795 out of 1393
# Article 796 out of 1393
# Article 797 out of 1393
# Article 798 out of 1393
# Article 799 out of 1393
# Article 800 out of 1393
# Article 801 out of 1393
# Article 802 out of 1393
# Article 803 out of 1393
# Article 804 out of 1393
# Article 805 out of 1393
# Article 806 out of 1393
# Article 807 out of 1393
# Article 808 out of 1393
# Article 809 out of 1393
# Article 810 out of 1393
# Article 811 out of 1393
# Article 812 out of 1393
# Article 813 out of 1393
# Article 814 out of 1393
# Article 815 out of 1393
# Article 816 out of 1393
# Article 817 out of 1393
# Article 818 out of 1393
# Article 819 out of 1393
# Article 820 out of 1393
# Article 821 out of 1393
# Article 822 out of 1393
# Article 823 out of 1393
# Article 824 out of 1393
# Article 825 out of 1393
# Article 826 out of 1393
# Article 827 out of 1393
# Article 828 out of 1393
# Article 829 out of 1393
# Article 830 out of 1393
# Article 831 out of 1393
# Article 832 out of 1393
# Article 833 out of 1393
# Article 834 out of 1393
# Article 835 out of 1393
# Article 836 out of 1393
# Article 837 out of 1393
# Article 838 out of 1393
# Article 839 out of 1393
# Article 840 out of 1393
# Article 841 out of 1393
# Article 842 out of 1393
# Article 843 out of 1393
# Article 844 out of 1393
# Article 845 out of 1393
# Article 846 out of 1393
# Article 847 out of 1393
# Article 848 out of 1393
# Article 849 out of 1393
# Article 850 out of 1393
# Article 851 out of 1393
# Article 852 out of 1393
# Article 853 out of 1393
# Article 854 out of 1393
# Article 855 out of 1393
# Article 856 out of 1393
# Article 857 out of 1393
# Article 858 out of 1393
# Article 859 out of 1393
# Article 860 out of 1393
# Article 861 out of 1393
# Article 862 out of 1393
# Article 863 out of 1393
# Article 864 out of 1393
# Article 865 out of 1393
# Article 866 out of 1393
# Article 867 out of 1393
# Article 868 out of 1393
# Article 869 out of 1393
# Article 870 out of 1393
# Article 871 out of 1393
# Article 872 out of 1393
# Article 873 out of 1393
# Article 874 out of 1393
# Article 875 out of 1393
# Article 876 out of 1393
# Article 877 out of 1393
# Article 878 out of 1393
# Article 879 out of 1393
# Article 880 out of 1393
# Article 881 out of 1393
# Article 882 out of 1393
# Article 883 out of 1393
# Article 884 out of 1393
# Article 885 out of 1393
# Article 886 out of 1393
# Article 887 out of 1393
# Article 888 out of 1393
# Article 889 out of 1393
# Article 890 out of 1393
# Article 891 out of 1393
# Article 892 out of 1393
# Article 893 out of 1393
# Article 894 out of 1393
# Article 895 out of 1393
# Article 896 out of 1393
# Article 897 out of 1393
# Article 898 out of 1393
# Article 899 out of 1393
# Article 900 out of 1393
# Article 901 out of 1393
# Article 902 out of 1393
# Article 903 out of 1393
# Article 904 out of 1393
# Article 905 out of 1393
# Article 906 out of 1393
# Article 907 out of 1393
# Article 908 out of 1393
# Article 909 out of 1393
# Article 910 out of 1393
# Article 911 out of 1393
# Article 912 out of 1393
# Article 913 out of 1393
# Article 914 out of 1393
# Article 915 out of 1393
# Article 916 out of 1393
# Article 917 out of 1393
# Article 918 out of 1393
# Article 919 out of 1393
# Article 920 out of 1393
# Article 921 out of 1393
# Article 922 out of 1393
# Article 923 out of 1393
# Article 924 out of 1393
# Article 925 out of 1393
# Article 926 out of 1393
# Article 927 out of 1393
# Article 928 out of 1393
# Article 929 out of 1393
# Article 930 out of 1393
# Article 931 out of 1393
# Article 932 out of 1393
# Article 933 out of 1393
# Article 934 out of 1393
# Article 935 out of 1393
# Article 936 out of 1393
# Article 937 out of 1393
# Article 938 out of 1393
# Article 939 out of 1393
# Article 940 out of 1393
# Article 941 out of 1393
# Article 942 out of 1393
# Article 943 out of 1393
# Article 944 out of 1393
# Article 945 out of 1393
# Article 946 out of 1393
# Article 947 out of 1393
# Article 948 out of 1393
# Article 949 out of 1393
# Article 950 out of 1393
# Article 951 out of 1393
# Article 952 out of 1393
# Article 953 out of 1393
# Article 954 out of 1393
# Article 955 out of 1393
# Article 956 out of 1393
# Article 957 out of 1393
# Article 958 out of 1393
# Article 959 out of 1393
# Article 960 out of 1393
# Article 961 out of 1393
# Article 962 out of 1393
# Article 963 out of 1393
# Article 964 out of 1393
# Article 965 out of 1393
# Article 966 out of 1393
# Article 967 out of 1393
# Article 968 out of 1393
# Article 969 out of 1393
# Article 970 out of 1393
# Article 971 out of 1393
# Article 972 out of 1393
# Article 973 out of 1393
# Article 974 out of 1393
# Article 975 out of 1393
# Article 976 out of 1393
# Article 977 out of 1393
# Article 978 out of 1393
# Article 979 out of 1393
# Article 980 out of 1393
# Article 981 out of 1393
# Article 982 out of 1393
# Article 983 out of 1393
# Article 984 out of 1393
# Article 985 out of 1393
# Article 986 out of 1393
# Article 987 out of 1393
# Article 988 out of 1393
# Article 989 out of 1393
# Article 990 out of 1393
# Article 991 out of 1393
# Article 992 out of 1393
# Article 993 out of 1393
# Article 994 out of 1393
# Article 995 out of 1393
# Article 996 out of 1393
# Article 997 out of 1393
# Article 998 out of 1393
# Article 999 out of 1393
# Article 1000 out of 1393
# Article 1001 out of 1393
# Article 1002 out of 1393
# Article 1003 out of 1393
# Article 1004 out of 1393
# Article 1005 out of 1393
# Article 1006 out of 1393
# Article 1007 out of 1393
# Article 1008 out of 1393
# Article 1009 out of 1393
# Article 1010 out of 1393
# Article 1011 out of 1393
# Article 1012 out of 1393
# Article 1013 out of 1393
# Article 1014 out of 1393
# Article 1015 out of 1393
# Article 1016 out of 1393
# Article 1017 out of 1393
# Article 1018 out of 1393
# Article 1019 out of 1393
# Article 1020 out of 1393
# Article 1021 out of 1393
# Article 1022 out of 1393
# Article 1023 out of 1393
# Article 1024 out of 1393
# Article 1025 out of 1393
# Article 1026 out of 1393
# Article 1027 out of 1393
# Article 1028 out of 1393
# Article 1029 out of 1393
# Article 1030 out of 1393
# Article 1031 out of 1393
# Article 1032 out of 1393
# Article 1033 out of 1393
# Article 1034 out of 1393
# Article 1035 out of 1393
# Article 1036 out of 1393
# Article 1037 out of 1393
# Article 1038 out of 1393
# Article 1039 out of 1393
# Article 1040 out of 1393
# Article 1041 out of 1393
# Article 1042 out of 1393
# Article 1043 out of 1393
# Article 1044 out of 1393
# Article 1045 out of 1393
# Article 1046 out of 1393
# Article 1047 out of 1393
# Article 1048 out of 1393
# Article 1049 out of 1393
# Article 1050 out of 1393
# Article 1051 out of 1393
# Article 1052 out of 1393
# Article 1053 out of 1393
# Article 1054 out of 1393
# Article 1055 out of 1393
# Article 1056 out of 1393
# Article 1057 out of 1393
# Article 1058 out of 1393
# Article 1059 out of 1393
# Article 1060 out of 1393
# Article 1061 out of 1393
# Article 1062 out of 1393
# Article 1063 out of 1393
# Article 1064 out of 1393
# Article 1065 out of 1393
# Article 1066 out of 1393
# Article 1067 out of 1393
# Article 1068 out of 1393
# Article 1069 out of 1393
# Article 1070 out of 1393
# Article 1071 out of 1393
# Article 1072 out of 1393
# Article 1073 out of 1393
# Article 1074 out of 1393
# Article 1075 out of 1393
# Article 1076 out of 1393
# Article 1077 out of 1393
# Article 1078 out of 1393
# Article 1079 out of 1393
# Article 1080 out of 1393
# Article 1081 out of 1393
# Article 1082 out of 1393
# Article 1083 out of 1393
# Article 1084 out of 1393
# Article 1085 out of 1393
# Article 1086 out of 1393
# Article 1087 out of 1393
# Article 1088 out of 1393
# Article 1089 out of 1393
# Article 1090 out of 1393
# Article 1091 out of 1393
# Article 1092 out of 1393
# Article 1093 out of 1393
# Article 1094 out of 1393
# Article 1095 out of 1393
# Article 1096 out of 1393
# Article 1097 out of 1393
# Article 1098 out of 1393
# Article 1099 out of 1393
# Article 1100 out of 1393
# Article 1101 out of 1393
# Article 1102 out of 1393
# Article 1103 out of 1393
# Article 1104 out of 1393
# Article 1105 out of 1393
# Article 1106 out of 1393
# Article 1107 out of 1393
# Article 1108 out of 1393
# Article 1109 out of 1393
# Article 1110 out of 1393
# Article 1111 out of 1393
# Article 1112 out of 1393
# Article 1113 out of 1393
# Article 1114 out of 1393
# Article 1115 out of 1393
# Article 1116 out of 1393
# Article 1117 out of 1393
# Article 1118 out of 1393
# Article 1119 out of 1393
# Article 1120 out of 1393
# Article 1121 out of 1393
# Article 1122 out of 1393
# Article 1123 out of 1393
# Article 1124 out of 1393
# Article 1125 out of 1393
# Article 1126 out of 1393
# Article 1127 out of 1393
# Article 1128 out of 1393
# Article 1129 out of 1393
# Article 1130 out of 1393
# Article 1131 out of 1393
# Article 1132 out of 1393
# Article 1133 out of 1393
# Article 1134 out of 1393
# Article 1135 out of 1393
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-3ff28d312b59> in <module>()
#      10
#      11 #        results=ag.disambiguate(new_content)
# ---> 12         results = systemparser.disambiguateAgdistis(new_content)
#      13         dis_entities={}
#      14         for dis_entity in results:
#
# ~/phd/Entities/EL-long-tail-phenomena/systemparser.py in disambiguateAgdistis(xmlText, type)
#      14         params={"text": xmlText, "type": type}
#      15         request = Request(agdistisUrl, urlencode(params).encode())
# ---> 16         thisJson = urlopen(request).read().decode()
#      17         return json.loads(thisJson)
#      18
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     221     else:
#     222         opener = _opener
# --> 223     return opener.open(url, data, timeout)
#     224
#     225 def install_opener(opener):
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/urllib/request.py in open(self, fullurl, data, timeout)
#     524             req = meth(req)
#     525
# --> 526         response = self._open(req, data)
#     527
#     528         # post-process response
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/urllib/request.py in _open(self, req, data)
#     542         protocol = req.type
#     543         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 544                                   '_open', req)
#     545         if result:
#     546             return result
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     502         for handler in handlers:
#     503             func = getattr(handler, meth_name)
# --> 504             result = func(*args)
#     505             if result is not None:
#     506                 return result
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/urllib/request.py in http_open(self, req)
#    1344
#    1345     def http_open(self, req):
# -> 1346         return self.do_open(http.client.HTTPConnection, req)
#    1347
#    1348     http_request = AbstractHTTPHandler.do_request_
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1319             except OSError as err: # timeout error
#    1320                 raise URLError(err)
# -> 1321             r = h.getresponse()
#    1322         except:
#    1323             h.close()
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/http/client.py in getresponse(self)
#    1329         try:
#    1330             try:
# -> 1331                 response.begin()
#    1332             except ConnectionError:
#    1333                 self.close()
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/http/client.py in begin(self)
#     295         # read until we get a non-100 response
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#     299                 break
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/http/client.py in _read_status(self)
#     256
#     257     def _read_status(self):
# --> 258         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     259         if len(line) > _MAXLINE:
#     260             raise LineTooLong("status line")
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %% [markdown]
# ### Debugging: Check if offsets between SYS and GOLD match for all entities

# %%
for articles in n3_articles:
    for entity in article.entity_mentions:
        if not entity.sys_link:
            print(entity.begin_index, entity.sys_link, entity.gold_link)

# %% [markdown]
# ### Store data on disk

# %%
load_utils.store_system_data(aida_title, 'agdistis', aida_articles)
#store_system_data(wes_title, 'agdistis', wes_articles)
load_utils.store_system_data(n3_title, 'agdistis', n3_articles)

# %% [markdown]
# ### 3) Run DBpedia Spotlight

# %%
import requests
import urllib.parse
import xml.etree.cElementTree as ET
from lxml import etree

spotlight_url="http://model.dbpedia-spotlight.org/en/disambiguate"
headers = {'Accept': 'application/json'}

for articles in [aida_articles,n3_articles]:

    c=0
    for article in articles:
        annotation = etree.Element("annotation", text=article.content)
        for mention in article.entity_mentions:
            sf = etree.SubElement(annotation, "surfaceForm")
            sf.set("name", mention.mention)
            sf.set("offset", str(mention.begin_index))
        my_xml=etree.tostring(annotation, xml_declaration=True, encoding='UTF-8')
        results=requests.post(spotlight_url, urllib.parse.urlencode({'text':my_xml, 'confidence': 0.5}), headers=headers)
        j=results.json()
        dis_entities={}
        if 'Resources' in j: resources=j['Resources']
        else: resources=[]
        for dis_entity in resources:
            dis_entities[str(dis_entity['@offset'])] = load_utils.getLinkRedirect(load_utils.normalizeURL(dis_entity['@URI']))
        for entity in article.entity_mentions:
            start = entity.begin_index
            if str(start) in dis_entities:
                dis_url = dis_entities[str(start)]
            else:
                dis_url = '--NME--'
            entity.sys_link = dis_url
        c+=1
        print("Article %d out of %d" % (c, len(articles)))
        time.sleep(0.1)
# Out:
# Article 1 out of 1393
# Article 2 out of 1393
# Article 3 out of 1393
# Article 4 out of 1393
# Article 5 out of 1393
# Article 6 out of 1393
# Article 7 out of 1393
# Article 8 out of 1393
# Article 9 out of 1393
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     379             try:  # Python 2.7, use buffering of HTTP responses
# --> 380                 httplib_response = conn.getresponse(buffering=True)
#     381             except TypeError:  # Python 2.6 and older, Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-64061691f14f> in <module>()
#      17             sf.set("offset", str(mention.begin_index))
#      18         my_xml=etree.tostring(annotation, xml_declaration=True, encoding='UTF-8')
# ---> 19         results=requests.post(spotlight_url, urllib.parse.urlencode({'text':my_xml, 'confidence': 0.5}), headers=headers)
#      20         j=results.json()
#      21         dis_entities={}
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/requests/api.py in post(url, data, json, **kwargs)
#     110     """
#     111
# --> 112     return request('post', url, data=data, json=json, **kwargs)
#     113
#     114
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/requests/api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     506         }
#     507         send_kwargs.update(settings)
# --> 508         resp = self.send(prep, **send_kwargs)
#     509
#     510         return resp
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     616
#     617         # Send the request
# --> 618         r = adapter.send(request, **kwargs)
#     619
#     620         # Total elapsed time of the request (approximately)
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438                     decode_content=False,
#     439                     retries=self.max_retries,
# --> 440                     timeout=timeout
#     441                 )
#     442
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   timeout=timeout_obj,
#     600                                                   body=body, headers=headers,
# --> 601                                                   chunked=chunked)
#     602
#     603             # If we're going to release the connection in ``finally:``, then
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     381             except TypeError:  # Python 2.6 and older, Python 3
#     382                 try:
# --> 383                     httplib_response = conn.getresponse()
#     384                 except Exception as e:
#     385                     # Remove the TypeError from the exception chain in Python 3;
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/http/client.py in getresponse(self)
#    1329         try:
#    1330             try:
# -> 1331                 response.begin()
#    1332             except ConnectionError:
#    1333                 self.close()
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/http/client.py in begin(self)
#     295         # read until we get a non-100 response
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#     299                 break
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/http/client.py in _read_status(self)
#     256
#     257     def _read_status(self):
# --> 258         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     259         if len(line) > _MAXLINE:
#     260             raise LineTooLong("status line")
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
load_utils.store_system_data(aida_title, 'spotlight', aida_articles)
#store_system_data(wes_title, 'spotlight', wes_articles)
#store_system_data(rss_title, 'spotlight', rss_articles)
load_utils.store_system_data(n3_title, 'spotlight', n3_articles)

# %% [markdown]
# ### 4) Run WAT

# %%
import json

wat_url='https://wat.d4science.org/wat/tag/json'
#wat_url='http://wikisense.mkapp.it/tag/disambiguate'

for articles in [aida_articles, n3_articles]:
    c=0
    for article in articles:
        txt = article.content
        spans=[]
        for mention in article.entity_mentions:
            span={'start': mention.begin_index,
                 'end': mention.end_index}
            spans.append(span)

        document_json = {
          "text": txt,
          "suggested_spans": spans
        }

        r = requests.get(wat_url, params={"document": json.dumps(document_json)})
        rjson=r.json()
        dis_entities={}
        for dis_entity in rjson['annotations']:
            dis_entities[str(dis_entity['start'])] = load_utils.getLinkRedirect(load_utils.normalizeURL(dis_entity['title']))
        for entity in article.entity_mentions:
            start = entity.begin_index
            if str(start) in dis_entities:
                dis_url = dis_entities[str(start)]
            else:
                dis_url = '--NME--'
            entity.sys_link = dis_url
        c+=1
        print("Article %d out of %d" % (c, len(articles)))
# Out:
# Article 1 out of 1393
# Article 2 out of 1393
# Article 3 out of 1393
# Article 4 out of 1393
# Article 5 out of 1393
# Article 6 out of 1393
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     379             try:  # Python 2.7, use buffering of HTTP responses
# --> 380                 httplib_response = conn.getresponse(buffering=True)
#     381             except TypeError:  # Python 2.6 and older, Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-a1c10e5a4a13> in <module>()
#      19         }
#      20
# ---> 21         r = requests.get(wat_url, params={"document": json.dumps(document_json)})
#      22         rjson=r.json()
#      23         dis_entities={}
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/requests/api.py in get(url, params, **kwargs)
#      70
#      71     kwargs.setdefault('allow_redirects', True)
# ---> 72     return request('get', url, params=params, **kwargs)
#      73
#      74
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/requests/api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     506         }
#     507         send_kwargs.update(settings)
# --> 508         resp = self.send(prep, **send_kwargs)
#     509
#     510         return resp
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     616
#     617         # Send the request
# --> 618         r = adapter.send(request, **kwargs)
#     619
#     620         # Total elapsed time of the request (approximately)
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438                     decode_content=False,
#     439                     retries=self.max_retries,
# --> 440                     timeout=timeout
#     441                 )
#     442
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   timeout=timeout_obj,
#     600                                                   body=body, headers=headers,
# --> 601                                                   chunked=chunked)
#     602
#     603             # If we're going to release the connection in ``finally:``, then
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     381             except TypeError:  # Python 2.6 and older, Python 3
#     382                 try:
# --> 383                     httplib_response = conn.getresponse()
#     384                 except Exception as e:
#     385                     # Remove the TypeError from the exception chain in Python 3;
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/http/client.py in getresponse(self)
#    1329         try:
#    1330             try:
# -> 1331                 response.begin()
#    1332             except ConnectionError:
#    1333                 self.close()
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/http/client.py in begin(self)
#     295         # read until we get a non-100 response
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#     299                 break
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/http/client.py in _read_status(self)
#     256
#     257     def _read_status(self):
# --> 258         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     259         if len(line) > _MAXLINE:
#     260             raise LineTooLong("status line")
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     278     def recv_into(self, *args, **kwargs):
#     279         try:
# --> 280             return self.connection.recv_into(*args, **kwargs)
#     281         except OpenSSL.SSL.SysCallError as e:
#     282             if self.suppress_ragged_eofs and e.args == (-1, 'Unexpected EOF'):
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/OpenSSL/SSL.py in recv_into(self, buffer, nbytes, flags)
#    1620             result = _lib.SSL_peek(self._ssl, buf, nbytes)
#    1621         else:
# -> 1622             result = _lib.SSL_read(self._ssl, buf, nbytes)
#    1623         self._raise_ssl_error(self._ssl, result)
#    1624
#
# KeyboardInterrupt:

# %%
load_utils.store_system_data(n3_title, 'wat', n3_articles)
load_utilsstore_system_data(aida_title, 'wat', aida_articles)
#store_system_data(wes_title, 'wat', wes_articles)
